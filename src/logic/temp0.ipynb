# %%
import os
from dotenv import load_dotenv

load_dotenv()

endpoint = os.getenv('AZURE_OPENAI_ENDPOINT')
api_key = os.getenv('AZURE_OPENAI_API_KEY')
vector_store_id = os.getenv('AZURE_VECTOR_STORE_ID')
endpoint
# Out:
# 'team1-openai-sc.openai.azure.com'

# %% [markdown]
# ### Key Authentication

# %%
import requests

url = f'https://{endpoint}/openai/assistants?api-version=2024-05-01-preview'
result = requests.post(
    url, 
    headers={
        'Authorization': 'Bearer YOUR_ACCESS_TOKEN',
        'api-key': api_key,
        'Content-Type': 'application/json'
    }, 
    json={
        "instructions": "시스템 지시사항이 여기에 들어갑니다.",
        "name": "도우미 이름",
        "tools": [
            {
            "type": "file_search"
            }
        ],
        "model": "gpt-4o",
        "tool_resources": {
            "file_search": {
            "vector_store_ids": [
                vector_store_id
            ]
            }
        },
        "temperature": 1,
        "top_p": 1
    }
)
result
# Out:
# <Response [200]>

# %%
result.json()
# Out:
# {'id': 'asst_pyrOWbCC8KGhObjjhr2UXg6H',
#  'object': 'assistant',
#  'created_at': 1744097186,
#  'name': '도우미 이름',
#  'description': None,
#  'model': 'gpt-4o',
#  'instructions': '시스템 지시사항이 여기에 들어갑니다.',
#  'tools': [{'type': 'file_search'}],
#  'top_p': 1.0,
#  'temperature': 1.0,
#  'tool_resources': {'file_search': {'vector_store_ids': ['vs_tfjfiRm96tCMQzueruozXHwp']}},
#  'metadata': {},
#  'response_format': 'auto'}

# %%
assistant_id = result.json()['id']

# %% [markdown]
# ### Create a thread

# %%
url = f'https://{endpoint}/openai/threads?api-version=2024-05-01-preview'

result = requests.post(
    url, 
    headers={
        'api-key': api_key,
        'Content-Type': 'application/json'
    }
)
result
# Out:
# <Response [200]>

# %%
result.json()
# Out:
# {'id': 'thread_RNL7XsFOY5Xr8GjB3aMrOJku',
#  'object': 'thread',
#  'created_at': 1744097191,
#  'metadata': {},
#  'tool_resources': {}}

# %%
thread_id = result.json()['id']

# %% [markdown]
# ### Add a user question to the thread

# %%
url = f'https://{endpoint}/openai/threads/{thread_id}/messages?api-version=2024-05-01-preview'

result = requests.post(
    url, 
    headers={
        'api-key': api_key,
        'Content-Type': 'application/json'
    },
    json={
        'role': 'user',
        'content': '안녕하세요'
    }
)
result
# Out:
# <Response [200]>

# %%
result.json()
# Out:
# {'id': 'msg_ojaWF42eiwWGLihY6zFqpJVz',
#  'object': 'thread.message',
#  'created_at': 1744097431,
#  'assistant_id': None,
#  'thread_id': 'thread_RNL7XsFOY5Xr8GjB3aMrOJku',
#  'run_id': None,
#  'role': 'user',
#  'content': [{'type': 'text', 'text': {'value': '안녕하세요', 'annotations': []}}],
#  'attachments': [],
#  'metadata': {}}

# %% [markdown]
# ### Run the thread

# %%
url = f'https://{endpoint}/openai/threads/{thread_id}/runs?api-version=2024-05-01-preview'

result = requests.post(
    url, 
    headers={
        'api-key': api_key,
        'Content-Type': 'application/json'
    },
    json={
        'assistant_id': assistant_id
    }
)
result
# Out:
# <Response [200]>

# %%
result.json()
# Out:
# {'id': 'run_OVjAOoMVbWCcS35PwmejJstn',
#  'object': 'thread.run',
#  'created_at': 1744097432,
#  'assistant_id': 'asst_pyrOWbCC8KGhObjjhr2UXg6H',
#  'thread_id': 'thread_RNL7XsFOY5Xr8GjB3aMrOJku',
#  'status': 'queued',
#  'started_at': None,
#  'expires_at': 1744098032,
#  'cancelled_at': None,
#  'failed_at': None,
#  'completed_at': None,
#  'required_action': None,
#  'last_error': None,
#  'model': 'gpt-4o',
#  'instructions': '시스템 지시사항이 여기에 들어갑니다.',
#  'tools': [{'type': 'file_search'}],
#  'tool_resources': {},
#  'metadata': {},
#  'temperature': 1.0,
#  'top_p': 1.0,
#  'max_completion_tokens': None,
#  'max_prompt_tokens': None,
#  'truncation_strategy': {'type': 'auto', 'last_messages': None},
#  'incomplete_details': None,
#  'usage': None,
#  'response_format': 'auto',
#  'tool_choice': 'auto',
#  'parallel_tool_calls': True}

# %%
run_id = result.json()['id']

# %% [markdown]
# ### Get the status of the run

# %%
url = f'https://{endpoint}/openai/threads/{thread_id}/runs/{run_id}?api-version=2024-05-01-preview'

result = requests.get(
    url, 
    headers={
        'api-key': api_key,
    }
)
result
# Out:
# <Response [200]>

# %%
result.json()
# Out:
# {'id': 'run_OVjAOoMVbWCcS35PwmejJstn',
#  'object': 'thread.run',
#  'created_at': 1744097432,
#  'assistant_id': 'asst_pyrOWbCC8KGhObjjhr2UXg6H',
#  'thread_id': 'thread_RNL7XsFOY5Xr8GjB3aMrOJku',
#  'status': 'in_progress',
#  'started_at': 1744097433,
#  'expires_at': 1744098032,
#  'cancelled_at': None,
#  'failed_at': None,
#  'completed_at': None,
#  'required_action': None,
#  'last_error': None,
#  'model': 'gpt-4o',
#  'instructions': '시스템 지시사항이 여기에 들어갑니다.',
#  'tools': [{'type': 'file_search'}],
#  'tool_resources': {},
#  'metadata': {},
#  'temperature': 1.0,
#  'top_p': 1.0,
#  'max_completion_tokens': None,
#  'max_prompt_tokens': None,
#  'truncation_strategy': {'type': 'auto', 'last_messages': None},
#  'incomplete_details': None,
#  'usage': None,
#  'response_format': 'auto',
#  'tool_choice': 'auto',
#  'parallel_tool_calls': True}

# %% [markdown]
# ### See the Assistant response

# %%
url = f'https://{endpoint}/openai/threads/{thread_id}/messages?api-version=2024-05-01-preview'

result = requests.get(
    url, 
    headers={
        'api-key': api_key,
        'Content-Type': 'application/json'
    }
)
result
# Out:
# <Response [200]>

# %%
result.json()
# Out:
# {'object': 'list',
#  'data': [{'id': 'msg_NxcOe4MG1yUBAkxI4Ho1caFa',
#    'object': 'thread.message',
#    'created_at': 1744097433,
#    'assistant_id': 'asst_pyrOWbCC8KGhObjjhr2UXg6H',
#    'thread_id': 'thread_RNL7XsFOY5Xr8GjB3aMrOJku',
#    'run_id': 'run_OVjAOoMVbWCcS35PwmejJstn',
#    'role': 'assistant',
#    'content': [{'type': 'text',
#      'text': {'value': '안녕하세요! 어떻게 도와드릴까요? 😊', 'annotations': []}}],
#    'attachments': [],
#    'metadata': {}},
#   {'id': 'msg_ojaWF42eiwWGLihY6zFqpJVz',
#    'object': 'thread.message',
#    'created_at': 1744097431,
#    'assistant_id': None,
#    'thread_id': 'thread_RNL7XsFOY5Xr8GjB3aMrOJku',
#    'run_id': None,
#    'role': 'user',
#    'content': [{'type': 'text',
#      'text': {'value': '안녕하세요', 'annotations': []}}],
#    'attachments': [],
#    'metadata': {}},
#   {'id': 'msg_IS9r6Mz8N6458gpvyaVQwqR4',
#    'object': 'thread.message',
#    'created_at': 1744097381,
#    'assistant_id': None,
#    'thread_id': 'thread_RNL7XsFOY5Xr8GjB3aMrOJku',
#    'run_id': None,
#    'role': 'user',
#    'content': [{'type': 'text',
#      'text': {'value': '안녕하세요', 'annotations': []}}],
#    'attachments': [],
#    'metadata': {}},
#   {'id': 'msg_vhkmE1qDZJu0suK0XzBSbPo4',
#    'object': 'thread.message',
#    'created_at': 1744097194,
#    'assistant_id': 'asst_pyrOWbCC8KGhObjjhr2UXg6H',
#    'thread_id': 'thread_RNL7XsFOY5Xr8GjB3aMrOJku',
#    'run_id': 'run_dUbZ56U0RU0ymVvUuqIjTYBW',
#    'role': 'assistant',
#    'content': [{'type': 'text',
#      'text': {'value': '안녕하세요! 도움이 필요하시면 말씀해주세요. 파일을 업로드하셨으니 관련된 질문이 있다면 말씀해 주시면 자료를 검색해 드리겠습니다. 😊',
#       'annotations': []}}],
#    'attachments': [],
#    'metadata': {}},
#   {'id': 'msg_Qen2rIQ3XihdNbReJJa58W41',
#    'object': 'thread.message',
#    'created_at': 1744097192,
#    'assistant_id': None,
#    'thread_id': 'thread_RNL7XsFOY5Xr8GjB3aMrOJku',
#    'run_id': None,
#    'role': 'user',
#    'content': [{'type': 'text',
#      'text': {'value': '안녕하세요', 'annotations': []}}],
#    'attachments': [],
#    'metadata': {}}],
#  'first_id': 'msg_NxcOe4MG1yUBAkxI4Ho1caFa',
#  'last_id': 'msg_Qen2rIQ3XihdNbReJJa58W41',
#  'has_more': False}
